# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %%
#Values
E_sper1 = [0]
E_th1 = [0]
E_sper2 = [2000, 4318.8, 4804.2, 6478.2]
E_th2 = [2000, 4318.8, 2866.955, 6347.75]
E_sper3 = [8104.5 , 9780]
E_th3 = [8104.5, 9553.7]
E_sper4 = [ 9645,  11030, 13330, 15590, 18200]
E_th4 = [ 9645, 11094.2, 13123.2, 15731.85, 18929.2]

# %%
etichette_sper1 = ['3/2⁻₁']
etichette_th1 = ['3/2⁻₁']
etichette_sper2 = ['1/2⁻₁', '5/2⁻₁', '3/2⁻₂', '7/2⁻₁']
etichette_th2 = [ '1/2⁻₁', '5/2⁻₁', '3/2⁻₂', '7/2⁻₁']
etichette_sper3 = ['3/2⁻₃', '5/2⁻₂']
etichette_th3 = ['3/2⁻₃', '5/2⁻₂']
etichette_sper4 = ['3/2⁻₄', '5/2⁻₃', '7/2⁻₂', '9/2⁻₁', '11/2⁻₁']
etichette_th4 = ['3/2⁻₄', '5/2⁻₃', '7/2⁻₂', '9/2⁻₁', '11/2⁻₁']

# %%
plt.figure(figsize=(8, 10))
legend_labels = []

for y, etichetta in zip(E_sper1, etichette_sper1):
    plt.hlines(y=y, xmin=1.2, xmax=1.25, color='skyblue', linewidth=2)
    plt.text(1.13, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y}')

for y, etichetta in zip(E_th1, etichette_th1):
    plt.hlines(y=y, xmin=1.35, xmax=1.4, color='orange', linewidth=2)
    plt.text(1.41, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y:.2f}')

for i in range(len(E_sper1)):
    plt.plot([1.25, 1.35], [E_sper1[i], E_th1[i]], linestyle='--', color='gray', linewidth=1)

for y, etichetta in zip(E_sper2, etichette_sper2):
    plt.hlines(y=y, xmin=1.48, xmax=1.53, color='skyblue', linewidth=2)
    plt.text(1.41, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y}')

for y, etichetta in zip(E_th2, etichette_th2):
    plt.hlines(y=y, xmin=1.63, xmax=1.68, color='orange', linewidth=2)
    plt.text(1.69, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y:.2f}')

for i in range(len(E_sper2)):
    plt.plot([1.53, 1.63], [E_sper2[i], E_th2[i]], linestyle='--', color='gray', linewidth=1)

for y, etichetta in zip(E_sper3, etichette_sper3):
    plt.hlines(y=y, xmin=1.76, xmax=1.81, color='skyblue', linewidth=2)
    plt.text(1.69, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y}')

for y, etichetta in zip(E_th3, etichette_th3):
    plt.hlines(y=y, xmin=1.91, xmax=1.96, color='orange', linewidth=2)
    plt.text(1.97, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y:.2f}')

for i in range(len(E_sper3)):
    plt.plot([1.81, 1.91], [E_sper3[i], E_th3[i]], linestyle='--', color='gray', linewidth=1)


for y,etichetta in zip(E_sper4, etichette_sper4):
    plt.hlines(y=y, xmin=2.07, xmax=2.13, color='skyblue', linewidth=2) 
    plt.text(2.03, y+0.3, f'{etichetta}', verticalalignment='center', fontsize=8)    
    #legend_labels.append(f'{etichetta}: {y}')

for y,etichetta in zip(E_th4, etichette_th4):
    plt.hlines(y=y, xmin=2.23, xmax=2.28, color='orange', linewidth=2)
    plt.text(2.29, y, f'{etichetta}', verticalalignment='center', fontsize=8)
    #legend_labels.append(f'{etichetta}: {y:.2f}')

for i in range(len(E_sper4)):
    plt.plot([2.13, 2.23], [E_sper4[i], E_th4[i]], linestyle='--', color='gray', linewidth=1)

sperimentale = mlines.Line2D([], [], color='skyblue', linewidth=2, label='Sperimentale')
teorico = mlines.Line2D([], [], color='orange', linewidth=2, label='Teorico')

plt.legend(handles=[sperimentale, teorico], loc='upper left', fontsize=10, title='Legenda')

plt.xticks([1.3, 1.58, 1.86, 2.18], ['J1=3/2, JR=0', 'J1=3/2, JR=2', 'J1=1/2, JR=2', 'J1=7/2, JR=2'])
plt.xlim(1, 2.4)
plt.xlabel('Bande rotazionali')
plt.ylabel('Energia (keV)')
#plt.title('Spettro Energetico: Energie Sperimentali e Teoriche')
#plt.grid(True, axis='y', linestyle='--', alpha=0.7)
#plt.savefig('C:/Users/Marco/OneDrive/Desktop/divisionebande.png', format='png', dpi=300)
