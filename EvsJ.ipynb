# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Values
E_sper = [0, 2000, 4318.8, 4804.2, 6478.2, 8104.5 , 8420, 9645, 9780, 9970, 12510]
J1=[3.75, 0.75, 8.75, 3.75, 15.75, 3.75,8.75, 3.75, 8.75, 15.75, 0.75]  

E_sper1 = [11030, 13330, 15590, 18200]
J3=[8.75, 15.75, 24.75, 35.75]

E_th = [0, 2000, 4318.8, 2866.96, 6347.75, 8104.5, 9553.7, 9645, 11094.2, 13123.2, 15731.85, 18929.2]
J2=[3.75, 0.75, 8.75, 3.75, 15.75, 3.75, 8.75, 3.75, 8.75, 15.75, 24.75, 35.75]

# %%
etichette_sper = ['3/2⁻₁', '1/2⁻₁', '5/2⁻₁', '3/2⁻₂', '7/2⁻₁', '3/2⁻₃', '5/2⁻₂', '3/2⁻₄', '5/2⁻₃', '7/2⁻₂', '1/2⁻₂']
etichette_th = ['3/2⁻₁', '1/2⁻₁', '5/2⁻₁', '3/2⁻₂', '7/2⁻₁', '3/2⁻₃', '5/2⁻₃', '3/2⁻₄', '5/2⁻₄', '7/2⁻₃', '9/2⁻₁', '11/2⁻₁']

pi=str(np.pi)
legend_labels = [
    'Punti sperimentali',
    'Punti teorici',
    'Punti sperimentali(senza Jπ)'
]

# %%
print(len(etichette_sper))

# %%
for etichetta, j, e in zip(etichette_sper, J1, E_sper):
    plt.annotate(etichetta, (j, e), 
                 textcoords="offset points", xytext=(5, 5), 
                 ha='center', fontsize=8, color='black')

for etichetta, j, e in zip(etichette_th, J2, E_th):
    plt.annotate(etichetta, (j, e), 
                 textcoords="offset points", xytext=(5, 5), 
                 ha='center', fontsize=8, color='black')

plt.scatter(J1, E_sper, color='skyblue', label=legend_labels[0], marker='o')  
plt.scatter(J3, E_sper1, color='green', label=legend_labels[1], marker='o')  
plt.scatter(J2, E_th, color='orange', label=legend_labels[2], marker='o')

plt.legend(loc='lower right', fontsize=8, title='Livelli Energetici')

plt.xticks([0, 5, 10, 15, 20, 25, 30, 35, 40], ['0', '5','10', '15', '20', '25', '30', '35', '40'])
plt.xlim(0, 45)
plt.ylim(0, 20000)

plt.xlabel('J(J+1)')
plt.ylabel('Energia (keV)')
#plt.title('Spettro Energetico: Energie Sperimentale')
plt.grid(True, linestyle='--', alpha=0.7)
#plt.savefig('C:/Users/Marco/OneDrive/Desktop/EvsJ.pdf', dpi=300)
